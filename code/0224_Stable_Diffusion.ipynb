# %%
# !pip install -r requirements.txt -q
from PIL import Image
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 716.4/716.4 KB 12.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 KB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 87.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.0/144.0 KB 19.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 27.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.2/92.2 MB 10.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 99.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 24.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 KB 17.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Text To Image

# %%
module = "texttoimage"
token = "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"
prompt = "cyberpunk city"
seed = ""

# %%
# Text To Image
# !python stable_diffusion_total.py \
--module="$module" \
--token="$token" \
--prompt="$prompt" \
--seed="$seed"
# Out:
# /usr/local/lib/python3.8/dist-packages/xformers/_C.so: undefined symbol: _ZNK3c104impl13OperatorEntry20reportSignatureErrorENS0_12CppSignatureE
# WARNING:root:WARNING: /usr/local/lib/python3.8/dist-packages/xformers/_C.so: undefined symbol: _ZNK3c104impl13OperatorEntry20reportSignatureErrorENS0_12CppSignatureE
# Need to compile C++ extensions to get sparse attention suport. Please run python setup.py build develop
# WARNING:root:A matching Triton is not available, some optimizations will not be enabled.
# Error caught was: No module named 'triton'
# 2023-02-24 01:50:25.237956: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
from PIL import Image
Image.open("/content/TexttoImage/T2I_cyberpunk city_772176995.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7FA91F542FD0>

# %% [markdown]
# ## Image to Image

# %%
module = "imagetoimage"
token = "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"
file_name = "/content/9984444A5BB495A00E.jfif"
prompt = "cyberpunk city"
strength = "0.6"
seed = ""

# %%
# !python stable_diffusion_total.py \
--module="$module" \
--token="$token" \
--prompt="$prompt" \
--file_name="$file_name" \
--strength="$strength" \
--seed="$seed"
# Out:
# /usr/local/lib/python3.8/dist-packages/xformers/_C.so: undefined symbol: _ZNK3c104impl13OperatorEntry20reportSignatureErrorENS0_12CppSignatureE
# WARNING:root:WARNING: /usr/local/lib/python3.8/dist-packages/xformers/_C.so: undefined symbol: _ZNK3c104impl13OperatorEntry20reportSignatureErrorENS0_12CppSignatureE
# Need to compile C++ extensions to get sparse attention suport. Please run python setup.py build develop
# WARNING:root:A matching Triton is not available, some optimizations will not be enabled.
# Error caught was: No module named 'triton'
# 2023-02-24 01:51:27.810471: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
from PIL import Image
Image.open("/content/ImagetoImage/I2I_cyberpunk city_344910080.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7FA91F5542B0>

# %% [markdown]
# ## Image Extend

# %%
module = "imageextend"
token = "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"
file_name = "/content/9984444A5BB495A00E.jfif"
prompt = "cyberpunk city"
a = 250
b = 250
seed = ""

# %%
# !python stable_diffusion_total.py \
    --module="$module" \
    --token="$token" \
    --prompt="$prompt" \
    --file_name="$file_name" \
    --a=$a \
    --b=$b \
    --seed="$seed"
# Out:
# /usr/local/lib/python3.8/dist-packages/xformers/_C.so: undefined symbol: _ZNK3c104impl13OperatorEntry20reportSignatureErrorENS0_12CppSignatureE
# WARNING:root:WARNING: /usr/local/lib/python3.8/dist-packages/xformers/_C.so: undefined symbol: _ZNK3c104impl13OperatorEntry20reportSignatureErrorENS0_12CppSignatureE
# Need to compile C++ extensions to get sparse attention suport. Please run python setup.py build develop
# WARNING:root:A matching Triton is not available, some optimizations will not be enabled.
# Error caught was: No module named 'triton'
# 2023-02-24 01:51:54.549356: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
Image.open("/content/ImageExtend/IEx_cyberpunk city_6820057910.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1081x910 at 0x7FA91F554E20>

# %% [markdown]
# ## Fine Tuning

# %%
module = "finetuning_env"
UNet_Training_Steps = 1500
UNet_Learning_Rate = 2e-6
Text_Encoder_Training_Steps = 350
Text_Encoder_Learning_Rate = 1e-6
Session_Name = "total_test_0224"
IMAGE_DIR = "/content/IU"

# %%
# !python stable_diffusion_total.py \
    --module="$module" \
    --UNet_Training_Steps="$UNet_Training_Steps" \
    --UNet_Learning_Rate="$UNet_Learning_Rate" \
    --Text_Encoder_Training_Steps="$Text_Encoder_Training_Steps" \
    --Text_Encoder_Learning_Rate="$Text_Encoder_Learning_Rate" \
    --Session_Name="$Session_Name" \
    --IMAGE_DIR="$IMAGE_DIR"
# Out:
# /usr/local/lib/python3.8/dist-packages/xformers/_C.so: undefined symbol: _ZNK3c104impl13OperatorEntry20reportSignatureErrorENS0_12CppSignatureE
# WARNING:root:WARNING: /usr/local/lib/python3.8/dist-packages/xformers/_C.so: undefined symbol: _ZNK3c104impl13OperatorEntry20reportSignatureErrorENS0_12CppSignatureE
# Need to compile C++ extensions to get sparse attention suport. Please run python setup.py build develop
# WARNING:root:A matching Triton is not available, some optimizations will not be enabled.
# Error caught was: No module named 'triton'
# 2023-02-24 05:39:35.796364: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
module = "finetuning"
UNet_Training_Steps = 100
UNet_Learning_Rate = 2e-6
Text_Encoder_Training_Steps = 100
Text_Encoder_Learning_Rate = 1e-6
Session_Name = "total_test_0224_3"
INSTANCE_DIR = "/content/IU"

# %%
# !accelerate launch stable_diffusion_total.py \
    --module="$module" \
    --UNet_Training_Steps="$UNet_Training_Steps" \
    --UNet_Learning_Rate="$UNet_Learning_Rate" \
    --Text_Encoder_Training_Steps="$Text_Encoder_Training_Steps" \
    --Text_Encoder_Learning_Rate="$Text_Encoder_Learning_Rate" \
    --Session_Name="$Session_Name" \
    --INSTANCE_DIR="$INSTANCE_DIR"
# Out:
# 2023-02-24 06:21:02.965490: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-24 06:21:03.915758: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-02-24 06:21:03.915875: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# ...

# %%
from glob import glob
IMAGE_DIR = "/content/IU"
file_list = glob(IMAGE_DIR + "/*")

# %%
INSTANCE_DIR = "/content/Inst"

# %%
import shutil
from tqdm import tqdm
for filename in tqdm(file_list, bar_format='  |{bar:15}| {n_fmt}/{total_fmt} Uploaded'):
    shutil.move(filename, INSTANCE_DIR)
# Out:
#   |███████████████| 21/21 Uploaded
